# %% [markdown]
# # Merge bigwig files by lineage

# %%
import pyBigWig
import numpy as np
import sys, os

bw_path = os.path.expanduser('~/UW/CutandRun/ATACbw')
# Get list of all .bw files in this folder
bw_files = [f for f in os.listdir(bw_path) if f.endswith('.bw')]
bw_files = [os.path.join(bw_path, f) for f in bw_files]

lineage_file = os.path.expanduser('~/UW/CutandRun/atac_lineages.lineages.txt')
lineages = np.genfromtxt(lineage_file, dtype=str, delimiter='\t')

unique_lineages = np.unique(lineages[:, 1])

for u, ul in enumerate(unique_lineages):
    cell_types = lineages[lineages[:, 1] == ul, 0]
    print(f"Lineage {u}: {ul}, Cell Types: {len(cell_types)}")
    # Open all files for this lineage
    bws = [pyBigWig.open(f) for f in bw_files if any(ct in f for ct in cell_types)]
    print(f"Found {len(bws)} bigWig files for lineage {ul}")
    # Get chromosome sizes from the first file
    chroms = bws[0].chroms()
    print(f"Chromosomes: {chroms}")
    # Output file
    out_bw = pyBigWig.open(f"{bw_path}/merged_sum_{ul}.bw", "w")
    
    out_bw.addHeader(list(chroms.items()))

    # Iterate over chromosomes
    for chrom, length in chroms.items():
        print(f"Processing chromosome: {chrom}, length: {length}")
        # Get values from each bw file for this chromosome
        all_vals = [bw.values(chrom, 0, length, numpy=True) for bw in bws]
        all_vals = np.array(all_vals)
        print(f"Shape of all_vals: {all_vals.shape}")
        
        # Sum values across all files, handle NaNs as 0
        summed_vals = np.nansum(all_vals, axis=0)
        
        # Replace any remaining NaNs with 0 and ensure float type
        summed_vals = np.nan_to_num(summed_vals, nan=0.0).astype(np.float64)
        
        # Convert to bedGraph-like blocks (start, end, value)
        if len(summed_vals) == 0:
            continue
            
        # Collect all intervals for this chromosome
        chrom_list = []
        starts_list = []
        ends_list = []
        values_list = []
        
        start = 0
        prev_val = summed_vals[0]
        
        for i in range(1, length):
            if summed_vals[i] != prev_val:
                # Only add non-zero values to reduce file size
                if prev_val != 0.0:
                    chrom_list.append(chrom)
                    starts_list.append(start)
                    ends_list.append(i)
                    values_list.append(float(prev_val))
                start = i
                prev_val = summed_vals[i]
        
        # Add the final block for this chromosome
        if prev_val != 0.0:
            chrom_list.append(chrom)
            starts_list.append(start)
            ends_list.append(length)
            values_list.append(float(prev_val))
        
        # Add all entries for this chromosome at once
        if chrom_list:  # Only add if we have entries
            print(f"Adding {len(chrom_list)} intervals for {chrom}")
            out_bw.addEntries(chroms=chrom_list, starts=starts_list, ends=ends_list, values=values_list)
        else:
            print(f"No non-zero intervals found for {chrom}")

    # Close files
    for bw in bws:
        bw.close()
    out_bw.close()
# Out:
# Lineage 0: B, Cell Types: 19
# Found 19 bigWig files for lineage B
# Chromosomes: {'chr1': 195471971, 'chr10': 130694993, 'chr11': 122082543, 'chr12': 120129022, 'chr13': 120421639, 'chr14': 124902244, 'chr15': 104043685, 'chr16': 98207768, 'chr17': 94987271, 'chr18': 90702639, 'chr19': 61431566, 'chr1_GL456210_random': 169725, 'chr1_GL456211_random': 241735, 'chr1_GL456212_random': 153618, 'chr1_GL456213_random': 39340, 'chr1_GL456221_random': 206961, 'chr2': 182113224, 'chr3': 160039680, 'chr4': 156508116, 'chr4_GL456216_random': 66673, 'chr4_GL456350_random': 227966, 'chr4_JH584292_random': 14945, 'chr4_JH584293_random': 207968, 'chr4_JH584294_random': 191905, 'chr4_JH584295_random': 1976, 'chr5': 151834684, 'chr5_GL456354_random': 195993, 'chr5_JH584296_random': 199368, 'chr5_JH584297_random': 205776, 'chr5_JH584298_random': 184189, 'chr5_JH584299_random': 953012, 'chr6': 149736546, 'chr7': 145441459, 'chr7_GL456219_random': 175968, 'chr8': 129401213, 'chr9': 124595110, 'chrM': 16299, 'chrUn_GL456239': 40056, 'chrUn_GL456359': 22974, 'chrUn_GL456360': 31704, 'chrUn_GL456366': 47073, 'chrUn_GL456367': 42057, 'chrUn_GL456368': 20208, 'chrUn_GL456370': 26764, 'chrUn_GL456372': 28664, 'chrUn_GL456378': 31602, 'chrUn_GL456379': 72385, 'chrUn_GL456381': 25871, 'chrUn_GL456382': 23158, 'chrUn_GL456383': 38659, 'chrUn_GL456385': 35240, 'chrUn_GL456387': 24685, 'chrUn_GL456389': 28772, 'chrUn_GL456390': 24668, 'chrUn_GL456392': 23629, 'chrUn_GL456393': 55711, 'chrUn_GL456394': 24323, 'chrUn_GL456396': 21240, 'chrUn_JH584304': 114452, 'chrX': 171031299, 'chrX_GL456233_random': 336933, 'chrY': 91744698, 'chrY_JH584300_random': 182347, 'chrY_JH584301_random': 259875, 'chrY_JH584302_random': 155838, 'chrY_JH584303_random': 158099}
# Processing chromosome: chr1, length: 195471971
# Shape of all_vals: (19, 195471971)
# Shape of all_vals: (19, 195471971)
# Adding 7106556 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Adding 7106556 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Shape of all_vals: (19, 130694993)
# Shape of all_vals: (19, 130694993)
# Adding 4712218 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Adding 4712218 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Shape of all_vals: (19, 122082543)
# Shape of all_vals: (19, 122082543)
# Adding 4505787 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Adding 4505787 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Shape of all_vals: (19, 120129022)
# Shape of all_vals: (19, 120129022)
# Adding 4231668 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Adding 4231668 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Shape of all_vals: (19, 120421639)
# Shape of all_vals: (19, 120421639)
# Adding 4298027 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Adding 4298027 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Shape of all_vals: (19, 124902244)
# Shape of all_vals: (19, 124902244)
# Adding 4263496 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Adding 4263496 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Shape of all_vals: (19, 104043685)
# Shape of all_vals: (19, 104043685)
# Adding 3749498 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Adding 3749498 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Shape of all_vals: (19, 98207768)
# Shape of all_vals: (19, 98207768)
# Adding 3517624 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Adding 3517624 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Shape of all_vals: (19, 94987271)
# Shape of all_vals: (19, 94987271)
# Adding 3386544 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Adding 3386544 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Shape of all_vals: (19, 90702639)
# Shape of all_vals: (19, 90702639)
# Adding 3274194 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Adding 3274194 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Shape of all_vals: (19, 61431566)
# Shape of all_vals: (19, 61431566)
# Adding 2184751 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (19, 169725)
# Adding 3236 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (19, 241735)
# Adding 3768 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (19, 153618)
# Adding 2225 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (19, 39340)
# Adding 4 intervals for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (19, 206961)
# Adding 2803 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Adding 2184751 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (19, 169725)
# Adding 3236 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (19, 241735)
# Adding 3768 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (19, 153618)
# Adding 2225 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (19, 39340)
# Adding 4 intervals for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (19, 206961)
# Adding 2803 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Shape of all_vals: (19, 182113224)
# Shape of all_vals: (19, 182113224)
# Adding 6594481 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Adding 6594481 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Shape of all_vals: (19, 160039680)
# Shape of all_vals: (19, 160039680)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 62
#      60     starts_list.append(start)
#      61     ends_list.append(i)
# ---> 62     values_list.append(float(prev_val))
#      63 start = i
#      64 prev_val = summed_vals[i]
#
# KeyboardInterrupt:

# %%
def merge_bigwig_by_lineage(bw_path, lineage_file, output_dir=None, window_size=None):
    """
    Merge BigWig files by lineage with optional windowing.
    
    Parameters:
    - bw_path: Path to directory containing BigWig files
    - lineage_file: Path to tab-delimited file with cell types and lineages
    - output_dir: Output directory (defaults to bw_path)
    - window_size: If specified, compute windowed averages instead of base-pair resolution

    - TODO: use numpy operations instead of for loop, or use joblib for parallelization

    Returns:
    - List of output file paths created
    """
    import pyBigWig
    import numpy as np
    import os
    
    if output_dir is None:
        output_dir = bw_path
    
    # Get list of all .bw files in this folder
    bw_files = [f for f in os.listdir(bw_path) if f.endswith('.bw')]
    bw_files = [os.path.join(bw_path, f) for f in bw_files]
    
    # Load lineage information
    lineages = np.genfromtxt(lineage_file, dtype=str, delimiter='\t')
    unique_lineages = np.unique(lineages[:, 1])
    
    output_files = []
    
    for u, ul in enumerate(unique_lineages):
        cell_types = lineages[lineages[:, 1] == ul, 0]
        print(f"Lineage {u}: {ul}, Cell Types: {len(cell_types)}")
        
        # Open all files for this lineage
        bws = [pyBigWig.open(f) for f in bw_files if any(ct in f for ct in cell_types)]
        print(f"Found {len(bws)} bigWig files for lineage {ul}")
        
        if len(bws) == 0:
            print(f"No files found for lineage {ul}, skipping...")
            continue
            
        # Get chromosome sizes from the first file
        chroms = bws[0].chroms()
        print(f"Chromosomes: {list(chroms.keys())}")
        
        # Output file
        if window_size:
            output_file = os.path.join(output_dir, f"merged_sum_{ul}_win{window_size}.bw")
        else:
            output_file = os.path.join(output_dir, f"merged_sum_{ul}.bw")
            
        out_bw = pyBigWig.open(output_file, "w")
        out_bw.addHeader(list(chroms.items()))
        
        # Iterate over chromosomes
        for chrom, length in chroms.items():
            print(f"Processing chromosome: {chrom}, length: {length}")
            
            # Get values from each bw file for this chromosome
            all_vals = [bw.values(chrom, 0, length, numpy=True) for bw in bws]
            all_vals = np.array(all_vals)
            print(f"Shape of all_vals: {all_vals.shape}")
            
            # Sum values across all files, handle NaNs as 0
            summed_vals = np.nansum(all_vals, axis=0)
            
            # Replace any remaining NaNs with 0 and ensure float type
            summed_vals = np.nan_to_num(summed_vals, nan=0.0).astype(np.float64)
            
            if len(summed_vals) == 0:
                continue
            
            # Apply windowing if specified
            if window_size:
                summed_vals = apply_windowing(summed_vals, window_size, length)
                # Update length to match windowed data
                windowed_length = len(summed_vals)
            else:
                windowed_length = length
            
            # Collect all intervals for this chromosome
            chrom_list = []
            starts_list = []
            ends_list = []
            values_list = []
            
            start = 0
            prev_val = summed_vals[0]
            
            for i in range(1, windowed_length):
                if i >= len(summed_vals):
                    break
                if summed_vals[i] != prev_val:
                    # Only add non-zero values to reduce file size
                    if prev_val != 0.0:
                        chrom_list.append(chrom)
                        if window_size:
                            # Convert windowed coordinates back to genomic coordinates
                            starts_list.append(start * window_size)
                            ends_list.append(i * window_size)
                        else:
                            starts_list.append(start)
                            ends_list.append(i)
                        values_list.append(float(prev_val))
                    start = i
                    prev_val = summed_vals[i]
            
            # Add the final block for this chromosome
            if prev_val != 0.0:
                chrom_list.append(chrom)
                if window_size:
                    starts_list.append(start * window_size)
                    ends_list.append(min(windowed_length * window_size, length))
                else:
                    starts_list.append(start)
                    ends_list.append(windowed_length)
                values_list.append(float(prev_val))
            
            # Add all entries for this chromosome at once
            if chrom_list:
                print(f"Adding {len(chrom_list)} intervals for {chrom}")
                out_bw.addEntries(chroms=chrom_list, starts=starts_list, ends=ends_list, values=values_list)
            else:
                print(f"No non-zero intervals found for {chrom}")
        
        # Close files
        for bw in bws:
            bw.close()
        out_bw.close()
        
        output_files.append(output_file)
        print(f"Created: {output_file}")
    
    return output_files


def apply_windowing(values, window_size, original_length):
    """
    Apply windowing to reduce resolution by averaging values within windows.
    
    Parameters:
    - values: 1D numpy array of values
    - window_size: Size of each window in base pairs
    - original_length: Original length of the chromosome
    
    Returns:
    - Windowed values array
    """
    import numpy as np
    
    # Calculate number of complete windows
    num_windows = len(values) // window_size
    
    if num_windows == 0:
        return np.array([np.mean(values)] if len(values) > 0 else [0.0])
    
    # Truncate to complete windows for easier reshaping
    truncated_values = values[:num_windows * window_size]
    
    # Reshape and compute mean for each window
    windowed = truncated_values.reshape(num_windows, window_size)
    window_means = np.mean(windowed, axis=1)
    
    # Handle any remaining bases in the last partial window
    remaining_bases = len(values) - (num_windows * window_size)
    if remaining_bases > 0:
        last_window_mean = np.mean(values[num_windows * window_size:])
        window_means = np.append(window_means, last_window_mean)
    
    return window_means

# %%
# Usage examples:

# Set up paths
bw_path = os.path.expanduser('~/UW/CutandRun/ATACbw')
lineage_file = os.path.expanduser('~/UW/CutandRun/atac_lineages.lineages.txt')

# Example 1: Merge at base-pair resolution (original functionality)
#print("=== Merging at base-pair resolution ===")
#output_files = merge_bigwig_by_lineage(bw_path, lineage_file)
#print(f"Created files: {output_files}")

# Example 2: Merge with 100bp windows
print("\n=== Merging with 100bp windows ===")
output_files_100bp = merge_bigwig_by_lineage(bw_path, lineage_file, window_size=100)
print(f"Created files: {output_files_100bp}")
# Out:
# === Merging with 100bp windows ===
# Lineage 0: B, Cell Types: 19
# Found 19 bigWig files for lineage B
# Chromosomes: ['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr1_GL456210_random', 'chr1_GL456211_random', 'chr1_GL456212_random', 'chr1_GL456213_random', 'chr1_GL456221_random', 'chr2', 'chr3', 'chr4', 'chr4_GL456216_random', 'chr4_GL456350_random', 'chr4_JH584292_random', 'chr4_JH584293_random', 'chr4_JH584294_random', 'chr4_JH584295_random', 'chr5', 'chr5_GL456354_random', 'chr5_JH584296_random', 'chr5_JH584297_random', 'chr5_JH584298_random', 'chr5_JH584299_random', 'chr6', 'chr7', 'chr7_GL456219_random', 'chr8', 'chr9', 'chrM', 'chrUn_GL456239', 'chrUn_GL456359', 'chrUn_GL456360', 'chrUn_GL456366', 'chrUn_GL456367', 'chrUn_GL456368', 'chrUn_GL456370', 'chrUn_GL456372', 'chrUn_GL456378', 'chrUn_GL456379', 'chrUn_GL456381', 'chrUn_GL456382', 'chrUn_GL456383', 'chrUn_GL456385', 'chrUn_GL456387', 'chrUn_GL456389', 'chrUn_GL456390', 'chrUn_GL456392', 'chrUn_GL456393', 'chrUn_GL456394', 'chrUn_GL456396', 'chrUn_JH584304', 'chrX', 'chrX_GL456233_random', 'chrY', 'chrY_JH584300_random', 'chrY_JH584301_random', 'chrY_JH584302_random', 'chrY_JH584303_random']
# Processing chromosome: chr1, length: 195471971
# Shape of all_vals: (19, 195471971)
# Shape of all_vals: (19, 195471971)
# Adding 1844787 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Adding 1844787 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Shape of all_vals: (19, 130694993)
# Shape of all_vals: (19, 130694993)
# Adding 1221300 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Adding 1221300 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Shape of all_vals: (19, 122082543)
# Shape of all_vals: (19, 122082543)
# Adding 1157413 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Adding 1157413 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Shape of all_vals: (19, 120129022)
# Shape of all_vals: (19, 120129022)
# Adding 1105722 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Adding 1105722 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Shape of all_vals: (19, 120421639)
# Shape of all_vals: (19, 120421639)
# Adding 1116510 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Adding 1116510 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Shape of all_vals: (19, 124902244)
# Shape of all_vals: (19, 124902244)
# Adding 1115126 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Adding 1115126 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Shape of all_vals: (19, 104043685)
# Shape of all_vals: (19, 104043685)
# Adding 971981 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Adding 971981 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Shape of all_vals: (19, 98207768)
# Shape of all_vals: (19, 98207768)
# Adding 913331 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Adding 913331 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Shape of all_vals: (19, 94987271)
# Shape of all_vals: (19, 94987271)
# Adding 878829 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Adding 878829 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Shape of all_vals: (19, 90702639)
# Shape of all_vals: (19, 90702639)
# Adding 845128 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Adding 845128 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Shape of all_vals: (19, 61431566)
# Shape of all_vals: (19, 61431566)
# Adding 564458 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (19, 169725)
# Adding 1096 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (19, 241735)
# Adding 1285 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (19, 153618)
# Adding 758 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (19, 39340)
# Adding 2 intervals for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (19, 206961)
# Adding 1002 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Adding 564458 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (19, 169725)
# Adding 1096 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (19, 241735)
# Adding 1285 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (19, 153618)
# Adding 758 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (19, 39340)
# Adding 2 intervals for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (19, 206961)
# Adding 1002 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Shape of all_vals: (19, 182113224)
# Shape of all_vals: (19, 182113224)
# Adding 1704299 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Adding 1704299 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Shape of all_vals: (19, 160039680)
# Shape of all_vals: (19, 160039680)
# Adding 1497225 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Adding 1497225 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Shape of all_vals: (19, 156508116)
# Shape of all_vals: (19, 156508116)
# Adding 1433789 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (19, 66673)
# Adding 612 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (19, 227966)
# Adding 11 intervals for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (19, 14945)
# Adding 136 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (19, 207968)
# Adding 11 intervals for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (19, 191905)
# Adding 8 intervals for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (19, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Adding 1433789 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (19, 66673)
# Adding 612 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (19, 227966)
# Adding 11 intervals for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (19, 14945)
# Adding 136 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (19, 207968)
# Adding 11 intervals for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (19, 191905)
# Adding 8 intervals for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (19, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Shape of all_vals: (19, 151834684)
# Shape of all_vals: (19, 151834684)
# Adding 1402757 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (19, 195993)
# Adding 247 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (19, 199368)
# Adding 131 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (19, 205776)
# Adding 170 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (19, 184189)
# Adding 31 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (19, 953012)
# Adding 1879 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Adding 1402757 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (19, 195993)
# Adding 247 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (19, 199368)
# Adding 131 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (19, 205776)
# Adding 170 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (19, 184189)
# Adding 31 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (19, 953012)
# Adding 1879 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Shape of all_vals: (19, 149736546)
# Shape of all_vals: (19, 149736546)
# Adding 1403211 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Adding 1403211 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Shape of all_vals: (19, 145441459)
# Shape of all_vals: (19, 145441459)
# Adding 1297279 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (19, 175968)
# Adding 14 intervals for chr7_GL456219_random
# Processing chromosome: chr8, length: 129401213
# Adding 1297279 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (19, 175968)
# Adding 14 intervals for chr7_GL456219_random
# Processing chromosome: chr8, length: 129401213
# Shape of all_vals: (19, 129401213)
# Shape of all_vals: (19, 129401213)
# Adding 1205880 intervals for chr8
# Processing chromosome: chr9, length: 124595110
# Adding 1205880 intervals for chr8
# Processing chromosome: chr9, length: 124595110
# Shape of all_vals: (19, 124595110)
# Shape of all_vals: (19, 124595110)
# Adding 1173481 intervals for chr9
# Processing chromosome: chrM, length: 16299
# Shape of all_vals: (19, 16299)
# No non-zero intervals found for chrM
# Processing chromosome: chrUn_GL456239, length: 40056
# Shape of all_vals: (19, 40056)
# Adding 401 intervals for chrUn_GL456239
# Processing chromosome: chrUn_GL456359, length: 22974
# Shape of all_vals: (19, 22974)
# Adding 218 intervals for chrUn_GL456359
# Processing chromosome: chrUn_GL456360, length: 31704
# Shape of all_vals: (19, 31704)
# Adding 283 intervals for chrUn_GL456360
# Processing chromosome: chrUn_GL456366, length: 47073
# Shape of all_vals: (19, 47073)
# Adding 381 intervals for chrUn_GL456366
# Processing chromosome: chrUn_GL456367, length: 42057
# Shape of all_vals: (19, 42057)
# Adding 344 intervals for chrUn_GL456367
# Processing chromosome: chrUn_GL456368, length: 20208
# Shape of all_vals: (19, 20208)
# Adding 149 intervals for chrUn_GL456368
# Processing chromosome: chrUn_GL456370, length: 26764
# Shape of all_vals: (19, 26764)
# Adding 181 intervals for chrUn_GL456370
# Processing chromosome: chrUn_GL456372, length: 28664
# Shape of all_vals: (19, 28664)
# Adding 190 intervals for chrUn_GL456372
# Processing chromosome: chrUn_GL456378, length: 31602
# Shape of all_vals: (19, 31602)
# Adding 287 intervals for chrUn_GL456378
# Processing chromosome: chrUn_GL456379, length: 72385
# Shape of all_vals: (19, 72385)
# Adding 595 intervals for chrUn_GL456379
# Processing chromosome: chrUn_GL456381, length: 25871
# Shape of all_vals: (19, 25871)
# Adding 208 intervals for chrUn_GL456381
# Processing chromosome: chrUn_GL456382, length: 23158
# Shape of all_vals: (19, 23158)
# Adding 147 intervals for chrUn_GL456382
# Processing chromosome: chrUn_GL456383, length: 38659
# Shape of all_vals: (19, 38659)
# Adding 300 intervals for chrUn_GL456383
# Processing chromosome: chrUn_GL456385, length: 35240
# Shape of all_vals: (19, 35240)
# Adding 315 intervals for chrUn_GL456385
# Processing chromosome: chrUn_GL456387, length: 24685
# Shape of all_vals: (19, 24685)
# Adding 187 intervals for chrUn_GL456387
# Processing chromosome: chrUn_GL456389, length: 28772
# Shape of all_vals: (19, 28772)
# Adding 232 intervals for chrUn_GL456389
# Processing chromosome: chrUn_GL456390, length: 24668
# Shape of all_vals: (19, 24668)
# Adding 132 intervals for chrUn_GL456390
# Processing chromosome: chrUn_GL456392, length: 23629
# Shape of all_vals: (19, 23629)
# Adding 226 intervals for chrUn_GL456392
# Processing chromosome: chrUn_GL456393, length: 55711
# Shape of all_vals: (19, 55711)
# Adding 484 intervals for chrUn_GL456393
# Processing chromosome: chrUn_GL456394, length: 24323
# Shape of all_vals: (19, 24323)
# Adding 210 intervals for chrUn_GL456394
# Processing chromosome: chrUn_GL456396, length: 21240
# Shape of all_vals: (19, 21240)
# Adding 192 intervals for chrUn_GL456396
# Processing chromosome: chrUn_JH584304, length: 114452
# Shape of all_vals: (19, 114452)
# Adding 726 intervals for chrUn_JH584304
# Processing chromosome: chrX, length: 171031299
# Adding 1173481 intervals for chr9
# Processing chromosome: chrM, length: 16299
# Shape of all_vals: (19, 16299)
# No non-zero intervals found for chrM
# Processing chromosome: chrUn_GL456239, length: 40056
# Shape of all_vals: (19, 40056)
# Adding 401 intervals for chrUn_GL456239
# Processing chromosome: chrUn_GL456359, length: 22974
# Shape of all_vals: (19, 22974)
# Adding 218 intervals for chrUn_GL456359
# Processing chromosome: chrUn_GL456360, length: 31704
# Shape of all_vals: (19, 31704)
# Adding 283 intervals for chrUn_GL456360
# Processing chromosome: chrUn_GL456366, length: 47073
# Shape of all_vals: (19, 47073)
# Adding 381 intervals for chrUn_GL456366
# Processing chromosome: chrUn_GL456367, length: 42057
# Shape of all_vals: (19, 42057)
# Adding 344 intervals for chrUn_GL456367
# Processing chromosome: chrUn_GL456368, length: 20208
# Shape of all_vals: (19, 20208)
# Adding 149 intervals for chrUn_GL456368
# Processing chromosome: chrUn_GL456370, length: 26764
# Shape of all_vals: (19, 26764)
# Adding 181 intervals for chrUn_GL456370
# Processing chromosome: chrUn_GL456372, length: 28664
# Shape of all_vals: (19, 28664)
# Adding 190 intervals for chrUn_GL456372
# Processing chromosome: chrUn_GL456378, length: 31602
# Shape of all_vals: (19, 31602)
# Adding 287 intervals for chrUn_GL456378
# Processing chromosome: chrUn_GL456379, length: 72385
# Shape of all_vals: (19, 72385)
# Adding 595 intervals for chrUn_GL456379
# Processing chromosome: chrUn_GL456381, length: 25871
# Shape of all_vals: (19, 25871)
# Adding 208 intervals for chrUn_GL456381
# Processing chromosome: chrUn_GL456382, length: 23158
# Shape of all_vals: (19, 23158)
# Adding 147 intervals for chrUn_GL456382
# Processing chromosome: chrUn_GL456383, length: 38659
# Shape of all_vals: (19, 38659)
# Adding 300 intervals for chrUn_GL456383
# Processing chromosome: chrUn_GL456385, length: 35240
# Shape of all_vals: (19, 35240)
# Adding 315 intervals for chrUn_GL456385
# Processing chromosome: chrUn_GL456387, length: 24685
# Shape of all_vals: (19, 24685)
# Adding 187 intervals for chrUn_GL456387
# Processing chromosome: chrUn_GL456389, length: 28772
# Shape of all_vals: (19, 28772)
# Adding 232 intervals for chrUn_GL456389
# Processing chromosome: chrUn_GL456390, length: 24668
# Shape of all_vals: (19, 24668)
# Adding 132 intervals for chrUn_GL456390
# Processing chromosome: chrUn_GL456392, length: 23629
# Shape of all_vals: (19, 23629)
# Adding 226 intervals for chrUn_GL456392
# Processing chromosome: chrUn_GL456393, length: 55711
# Shape of all_vals: (19, 55711)
# Adding 484 intervals for chrUn_GL456393
# Processing chromosome: chrUn_GL456394, length: 24323
# Shape of all_vals: (19, 24323)
# Adding 210 intervals for chrUn_GL456394
# Processing chromosome: chrUn_GL456396, length: 21240
# Shape of all_vals: (19, 21240)
# Adding 192 intervals for chrUn_GL456396
# Processing chromosome: chrUn_JH584304, length: 114452
# Shape of all_vals: (19, 114452)
# Adding 726 intervals for chrUn_JH584304
# Processing chromosome: chrX, length: 171031299
# Shape of all_vals: (19, 171031299)
# Shape of all_vals: (19, 171031299)
# Adding 1379732 intervals for chrX
# Processing chromosome: chrX_GL456233_random, length: 336933
# Shape of all_vals: (19, 336933)
# Adding 2881 intervals for chrX_GL456233_random
# Processing chromosome: chrY, length: 91744698
# Adding 1379732 intervals for chrX
# Processing chromosome: chrX_GL456233_random, length: 336933
# Shape of all_vals: (19, 336933)
# Adding 2881 intervals for chrX_GL456233_random
# Processing chromosome: chrY, length: 91744698
# Shape of all_vals: (19, 91744698)
# Shape of all_vals: (19, 91744698)
# Adding 109473 intervals for chrY
# Processing chromosome: chrY_JH584300_random, length: 182347
# Shape of all_vals: (19, 182347)
# Adding 4 intervals for chrY_JH584300_random
# Processing chromosome: chrY_JH584301_random, length: 259875
# Shape of all_vals: (19, 259875)
# Adding 14 intervals for chrY_JH584301_random
# Processing chromosome: chrY_JH584302_random, length: 155838
# Shape of all_vals: (19, 155838)
# No non-zero intervals found for chrY_JH584302_random
# Processing chromosome: chrY_JH584303_random, length: 158099
# Shape of all_vals: (19, 158099)
# Adding 3 intervals for chrY_JH584303_random
# Adding 109473 intervals for chrY
# Processing chromosome: chrY_JH584300_random, length: 182347
# Shape of all_vals: (19, 182347)
# Adding 4 intervals for chrY_JH584300_random
# Processing chromosome: chrY_JH584301_random, length: 259875
# Shape of all_vals: (19, 259875)
# Adding 14 intervals for chrY_JH584301_random
# Processing chromosome: chrY_JH584302_random, length: 155838
# Shape of all_vals: (19, 155838)
# No non-zero intervals found for chrY_JH584302_random
# Processing chromosome: chrY_JH584303_random, length: 158099
# Shape of all_vals: (19, 158099)
# Adding 3 intervals for chrY_JH584303_random
# Created: /home/sasse/UW/CutandRun/ATACbw/merged_sum_B_win100.bw
# Lineage 1: DC, Cell Types: 5
# Found 5 bigWig files for lineage DC
# Chromosomes: ['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr1_GL456210_random', 'chr1_GL456211_random', 'chr1_GL456212_random', 'chr1_GL456213_random', 'chr1_GL456221_random', 'chr2', 'chr3', 'chr4', 'chr4_GL456216_random', 'chr4_GL456350_random', 'chr4_JH584292_random', 'chr4_JH584293_random', 'chr4_JH584294_random', 'chr4_JH584295_random', 'chr5', 'chr5_GL456354_random', 'chr5_JH584296_random', 'chr5_JH584297_random', 'chr5_JH584298_random', 'chr5_JH584299_random', 'chr6', 'chr7', 'chr7_GL456219_random', 'chr8', 'chr9', 'chrM', 'chrUn_GL456239', 'chrUn_GL456359', 'chrUn_GL456360', 'chrUn_GL456366', 'chrUn_GL456367', 'chrUn_GL456368', 'chrUn_GL456370', 'chrUn_GL456372', 'chrUn_GL456378', 'chrUn_GL456379', 'chrUn_GL456381', 'chrUn_GL456382', 'chrUn_GL456383', 'chrUn_GL456385', 'chrUn_GL456387', 'chrUn_GL456389', 'chrUn_GL456390', 'chrUn_GL456392', 'chrUn_GL456393', 'chrUn_GL456394', 'chrUn_GL456396', 'chrUn_JH584304', 'chrX', 'chrX_GL456233_random', 'chrY', 'chrY_JH584300_random', 'chrY_JH584301_random', 'chrY_JH584302_random', 'chrY_JH584303_random']
# Processing chromosome: chr1, length: 195471971
# Created: /home/sasse/UW/CutandRun/ATACbw/merged_sum_B_win100.bw
# Lineage 1: DC, Cell Types: 5
# Found 5 bigWig files for lineage DC
# Chromosomes: ['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr1_GL456210_random', 'chr1_GL456211_random', 'chr1_GL456212_random', 'chr1_GL456213_random', 'chr1_GL456221_random', 'chr2', 'chr3', 'chr4', 'chr4_GL456216_random', 'chr4_GL456350_random', 'chr4_JH584292_random', 'chr4_JH584293_random', 'chr4_JH584294_random', 'chr4_JH584295_random', 'chr5', 'chr5_GL456354_random', 'chr5_JH584296_random', 'chr5_JH584297_random', 'chr5_JH584298_random', 'chr5_JH584299_random', 'chr6', 'chr7', 'chr7_GL456219_random', 'chr8', 'chr9', 'chrM', 'chrUn_GL456239', 'chrUn_GL456359', 'chrUn_GL456360', 'chrUn_GL456366', 'chrUn_GL456367', 'chrUn_GL456368', 'chrUn_GL456370', 'chrUn_GL456372', 'chrUn_GL456378', 'chrUn_GL456379', 'chrUn_GL456381', 'chrUn_GL456382', 'chrUn_GL456383', 'chrUn_GL456385', 'chrUn_GL456387', 'chrUn_GL456389', 'chrUn_GL456390', 'chrUn_GL456392', 'chrUn_GL456393', 'chrUn_GL456394', 'chrUn_GL456396', 'chrUn_JH584304', 'chrX', 'chrX_GL456233_random', 'chrY', 'chrY_JH584300_random', 'chrY_JH584301_random', 'chrY_JH584302_random', 'chrY_JH584303_random']
# Processing chromosome: chr1, length: 195471971
# Shape of all_vals: (5, 195471971)
# Shape of all_vals: (5, 195471971)
# Adding 1505293 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Adding 1505293 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Shape of all_vals: (5, 130694993)
# Shape of all_vals: (5, 130694993)
# Adding 1017732 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Adding 1017732 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Shape of all_vals: (5, 122082543)
# Shape of all_vals: (5, 122082543)
# Adding 968122 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Adding 968122 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Shape of all_vals: (5, 120129022)
# Shape of all_vals: (5, 120129022)
# Adding 907366 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Adding 907366 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Shape of all_vals: (5, 120421639)
# Shape of all_vals: (5, 120421639)
# Adding 917227 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Adding 917227 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Shape of all_vals: (5, 124902244)
# Shape of all_vals: (5, 124902244)
# Adding 906445 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Adding 906445 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Shape of all_vals: (5, 104043685)
# Shape of all_vals: (5, 104043685)
# Adding 807960 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Adding 807960 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Shape of all_vals: (5, 98207768)
# Shape of all_vals: (5, 98207768)
# Adding 750833 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Adding 750833 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Shape of all_vals: (5, 94987271)
# Shape of all_vals: (5, 94987271)
# Adding 715388 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Adding 715388 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Shape of all_vals: (5, 90702639)
# Shape of all_vals: (5, 90702639)
# Adding 693506 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Adding 693506 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Shape of all_vals: (5, 61431566)
# Shape of all_vals: (5, 61431566)
# Adding 462931 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (5, 169725)
# Adding 632 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (5, 241735)
# Adding 738 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (5, 153618)
# Adding 413 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (5, 39340)
# No non-zero intervals found for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (5, 206961)
# Adding 548 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Adding 462931 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (5, 169725)
# Adding 632 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (5, 241735)
# Adding 738 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (5, 153618)
# Adding 413 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (5, 39340)
# No non-zero intervals found for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (5, 206961)
# Adding 548 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Shape of all_vals: (5, 182113224)
# Shape of all_vals: (5, 182113224)
# Adding 1440224 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Adding 1440224 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Shape of all_vals: (5, 160039680)
# Shape of all_vals: (5, 160039680)
# Adding 1221984 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Adding 1221984 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Shape of all_vals: (5, 156508116)
# Shape of all_vals: (5, 156508116)
# Adding 1190554 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (5, 66673)
# Adding 405 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (5, 227966)
# No non-zero intervals found for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (5, 14945)
# Adding 99 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (5, 207968)
# Adding 3 intervals for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (5, 191905)
# No non-zero intervals found for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (5, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Adding 1190554 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (5, 66673)
# Adding 405 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (5, 227966)
# No non-zero intervals found for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (5, 14945)
# Adding 99 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (5, 207968)
# Adding 3 intervals for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (5, 191905)
# No non-zero intervals found for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (5, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Shape of all_vals: (5, 151834684)
# Shape of all_vals: (5, 151834684)
# Adding 1193530 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (5, 195993)
# Adding 90 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (5, 199368)
# Adding 56 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (5, 205776)
# Adding 69 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (5, 184189)
# Adding 4 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (5, 953012)
# Adding 901 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Adding 1193530 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (5, 195993)
# Adding 90 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (5, 199368)
# Adding 56 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (5, 205776)
# Adding 69 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (5, 184189)
# Adding 4 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (5, 953012)
# Adding 901 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Shape of all_vals: (5, 149736546)
# Shape of all_vals: (5, 149736546)
# Adding 1151484 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Adding 1151484 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Shape of all_vals: (5, 145441459)
# Shape of all_vals: (5, 145441459)
# Adding 1054530 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (5, 175968)
# Adding 8 intervals for chr7_GL456219_random
# Processing chromosome: chr8, length: 129401213
# Adding 1054530 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (5, 175968)
# Adding 8 intervals for chr7_GL456219_random
# Processing chromosome: chr8, length: 129401213
# Shape of all_vals: (5, 129401213)
# Shape of all_vals: (5, 129401213)
# Adding 1015486 intervals for chr8
# Processing chromosome: chr9, length: 124595110
# Adding 1015486 intervals for chr8
# Processing chromosome: chr9, length: 124595110
# Shape of all_vals: (5, 124595110)
# Shape of all_vals: (5, 124595110)
# Adding 970129 intervals for chr9
# Processing chromosome: chrM, length: 16299
# Shape of all_vals: (5, 16299)
# No non-zero intervals found for chrM
# Processing chromosome: chrUn_GL456239, length: 40056
# Shape of all_vals: (5, 40056)
# Adding 393 intervals for chrUn_GL456239
# Processing chromosome: chrUn_GL456359, length: 22974
# Shape of all_vals: (5, 22974)
# Adding 164 intervals for chrUn_GL456359
# Processing chromosome: chrUn_GL456360, length: 31704
# Shape of all_vals: (5, 31704)
# Adding 205 intervals for chrUn_GL456360
# Processing chromosome: chrUn_GL456366, length: 47073
# Shape of all_vals: (5, 47073)
# Adding 261 intervals for chrUn_GL456366
# Processing chromosome: chrUn_GL456367, length: 42057
# Shape of all_vals: (5, 42057)
# Adding 161 intervals for chrUn_GL456367
# Processing chromosome: chrUn_GL456368, length: 20208
# Shape of all_vals: (5, 20208)
# Adding 105 intervals for chrUn_GL456368
# Processing chromosome: chrUn_GL456370, length: 26764
# Shape of all_vals: (5, 26764)
# Adding 123 intervals for chrUn_GL456370
# Processing chromosome: chrUn_GL456372, length: 28664
# Shape of all_vals: (5, 28664)
# Adding 129 intervals for chrUn_GL456372
# Processing chromosome: chrUn_GL456378, length: 31602
# Shape of all_vals: (5, 31602)
# Adding 219 intervals for chrUn_GL456378
# Processing chromosome: chrUn_GL456379, length: 72385
# Shape of all_vals: (5, 72385)
# Adding 316 intervals for chrUn_GL456379
# Processing chromosome: chrUn_GL456381, length: 25871
# Shape of all_vals: (5, 25871)
# Adding 151 intervals for chrUn_GL456381
# Processing chromosome: chrUn_GL456382, length: 23158
# Shape of all_vals: (5, 23158)
# Adding 74 intervals for chrUn_GL456382
# Processing chromosome: chrUn_GL456383, length: 38659
# Shape of all_vals: (5, 38659)
# Adding 202 intervals for chrUn_GL456383
# Processing chromosome: chrUn_GL456385, length: 35240
# Shape of all_vals: (5, 35240)
# Adding 208 intervals for chrUn_GL456385
# Processing chromosome: chrUn_GL456387, length: 24685
# Shape of all_vals: (5, 24685)
# Adding 163 intervals for chrUn_GL456387
# Processing chromosome: chrUn_GL456389, length: 28772
# Shape of all_vals: (5, 28772)
# Adding 127 intervals for chrUn_GL456389
# Processing chromosome: chrUn_GL456390, length: 24668
# Shape of all_vals: (5, 24668)
# Adding 66 intervals for chrUn_GL456390
# Processing chromosome: chrUn_GL456392, length: 23629
# Shape of all_vals: (5, 23629)
# Adding 166 intervals for chrUn_GL456392
# Processing chromosome: chrUn_GL456393, length: 55711
# Shape of all_vals: (5, 55711)
# Adding 415 intervals for chrUn_GL456393
# Processing chromosome: chrUn_GL456394, length: 24323
# Shape of all_vals: (5, 24323)
# Adding 113 intervals for chrUn_GL456394
# Processing chromosome: chrUn_GL456396, length: 21240
# Shape of all_vals: (5, 21240)
# Adding 112 intervals for chrUn_GL456396
# Processing chromosome: chrUn_JH584304, length: 114452
# Shape of all_vals: (5, 114452)
# Adding 683 intervals for chrUn_JH584304
# Processing chromosome: chrX, length: 171031299
# Adding 970129 intervals for chr9
# Processing chromosome: chrM, length: 16299
# Shape of all_vals: (5, 16299)
# No non-zero intervals found for chrM
# Processing chromosome: chrUn_GL456239, length: 40056
# Shape of all_vals: (5, 40056)
# Adding 393 intervals for chrUn_GL456239
# Processing chromosome: chrUn_GL456359, length: 22974
# Shape of all_vals: (5, 22974)
# Adding 164 intervals for chrUn_GL456359
# Processing chromosome: chrUn_GL456360, length: 31704
# Shape of all_vals: (5, 31704)
# Adding 205 intervals for chrUn_GL456360
# Processing chromosome: chrUn_GL456366, length: 47073
# Shape of all_vals: (5, 47073)
# Adding 261 intervals for chrUn_GL456366
# Processing chromosome: chrUn_GL456367, length: 42057
# Shape of all_vals: (5, 42057)
# Adding 161 intervals for chrUn_GL456367
# Processing chromosome: chrUn_GL456368, length: 20208
# Shape of all_vals: (5, 20208)
# Adding 105 intervals for chrUn_GL456368
# Processing chromosome: chrUn_GL456370, length: 26764
# Shape of all_vals: (5, 26764)
# Adding 123 intervals for chrUn_GL456370
# Processing chromosome: chrUn_GL456372, length: 28664
# Shape of all_vals: (5, 28664)
# Adding 129 intervals for chrUn_GL456372
# Processing chromosome: chrUn_GL456378, length: 31602
# Shape of all_vals: (5, 31602)
# Adding 219 intervals for chrUn_GL456378
# Processing chromosome: chrUn_GL456379, length: 72385
# Shape of all_vals: (5, 72385)
# Adding 316 intervals for chrUn_GL456379
# Processing chromosome: chrUn_GL456381, length: 25871
# Shape of all_vals: (5, 25871)
# Adding 151 intervals for chrUn_GL456381
# Processing chromosome: chrUn_GL456382, length: 23158
# Shape of all_vals: (5, 23158)
# Adding 74 intervals for chrUn_GL456382
# Processing chromosome: chrUn_GL456383, length: 38659
# Shape of all_vals: (5, 38659)
# Adding 202 intervals for chrUn_GL456383
# Processing chromosome: chrUn_GL456385, length: 35240
# Shape of all_vals: (5, 35240)
# Adding 208 intervals for chrUn_GL456385
# Processing chromosome: chrUn_GL456387, length: 24685
# Shape of all_vals: (5, 24685)
# Adding 163 intervals for chrUn_GL456387
# Processing chromosome: chrUn_GL456389, length: 28772
# Shape of all_vals: (5, 28772)
# Adding 127 intervals for chrUn_GL456389
# Processing chromosome: chrUn_GL456390, length: 24668
# Shape of all_vals: (5, 24668)
# Adding 66 intervals for chrUn_GL456390
# Processing chromosome: chrUn_GL456392, length: 23629
# Shape of all_vals: (5, 23629)
# Adding 166 intervals for chrUn_GL456392
# Processing chromosome: chrUn_GL456393, length: 55711
# Shape of all_vals: (5, 55711)
# Adding 415 intervals for chrUn_GL456393
# Processing chromosome: chrUn_GL456394, length: 24323
# Shape of all_vals: (5, 24323)
# Adding 113 intervals for chrUn_GL456394
# Processing chromosome: chrUn_GL456396, length: 21240
# Shape of all_vals: (5, 21240)
# Adding 112 intervals for chrUn_GL456396
# Processing chromosome: chrUn_JH584304, length: 114452
# Shape of all_vals: (5, 114452)
# Adding 683 intervals for chrUn_JH584304
# Processing chromosome: chrX, length: 171031299
# Shape of all_vals: (5, 171031299)
# Shape of all_vals: (5, 171031299)
# Adding 811252 intervals for chrX
# Processing chromosome: chrX_GL456233_random, length: 336933
# Shape of all_vals: (5, 336933)
# Adding 1564 intervals for chrX_GL456233_random
# Processing chromosome: chrY, length: 91744698
# Adding 811252 intervals for chrX
# Processing chromosome: chrX_GL456233_random, length: 336933
# Shape of all_vals: (5, 336933)
# Adding 1564 intervals for chrX_GL456233_random
# Processing chromosome: chrY, length: 91744698
# Shape of all_vals: (5, 91744698)
# Shape of all_vals: (5, 91744698)
# Adding 40448 intervals for chrY
# Processing chromosome: chrY_JH584300_random, length: 182347
# Shape of all_vals: (5, 182347)
# Adding 2 intervals for chrY_JH584300_random
# Processing chromosome: chrY_JH584301_random, length: 259875
# Shape of all_vals: (5, 259875)
# Adding 3 intervals for chrY_JH584301_random
# Processing chromosome: chrY_JH584302_random, length: 155838
# Shape of all_vals: (5, 155838)
# No non-zero intervals found for chrY_JH584302_random
# Processing chromosome: chrY_JH584303_random, length: 158099
# Shape of all_vals: (5, 158099)
# Adding 1 intervals for chrY_JH584303_random
# Adding 40448 intervals for chrY
# Processing chromosome: chrY_JH584300_random, length: 182347
# Shape of all_vals: (5, 182347)
# Adding 2 intervals for chrY_JH584300_random
# Processing chromosome: chrY_JH584301_random, length: 259875
# Shape of all_vals: (5, 259875)
# Adding 3 intervals for chrY_JH584301_random
# Processing chromosome: chrY_JH584302_random, length: 155838
# Shape of all_vals: (5, 155838)
# No non-zero intervals found for chrY_JH584302_random
# Processing chromosome: chrY_JH584303_random, length: 158099
# Shape of all_vals: (5, 158099)
# Adding 1 intervals for chrY_JH584303_random
# Created: /home/sasse/UW/CutandRun/ATACbw/merged_sum_DC_win100.bw
# Lineage 2: ILC, Cell Types: 10
# Found 10 bigWig files for lineage ILC
# Chromosomes: ['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr1_GL456210_random', 'chr1_GL456211_random', 'chr1_GL456212_random', 'chr1_GL456213_random', 'chr1_GL456221_random', 'chr2', 'chr3', 'chr4', 'chr4_GL456216_random', 'chr4_GL456350_random', 'chr4_JH584292_random', 'chr4_JH584293_random', 'chr4_JH584294_random', 'chr4_JH584295_random', 'chr5', 'chr5_GL456354_random', 'chr5_JH584296_random', 'chr5_JH584297_random', 'chr5_JH584298_random', 'chr5_JH584299_random', 'chr6', 'chr7', 'chr7_GL456219_random', 'chr8', 'chr9', 'chrM', 'chrUn_GL456239', 'chrUn_GL456359', 'chrUn_GL456360', 'chrUn_GL456366', 'chrUn_GL456367', 'chrUn_GL456368', 'chrUn_GL456370', 'chrUn_GL456372', 'chrUn_GL456378', 'chrUn_GL456379', 'chrUn_GL456381', 'chrUn_GL456382', 'chrUn_GL456383', 'chrUn_GL456385', 'chrUn_GL456387', 'chrUn_GL456389', 'chrUn_GL456390', 'chrUn_GL456392', 'chrUn_GL456393', 'chrUn_GL456394', 'chrUn_GL456396', 'chrUn_JH584304', 'chrX', 'chrX_GL456233_random', 'chrY', 'chrY_JH584300_random', 'chrY_JH584301_random', 'chrY_JH584302_random', 'chrY_JH584303_random']
# Processing chromosome: chr1, length: 195471971
# Created: /home/sasse/UW/CutandRun/ATACbw/merged_sum_DC_win100.bw
# Lineage 2: ILC, Cell Types: 10
# Found 10 bigWig files for lineage ILC
# Chromosomes: ['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr1_GL456210_random', 'chr1_GL456211_random', 'chr1_GL456212_random', 'chr1_GL456213_random', 'chr1_GL456221_random', 'chr2', 'chr3', 'chr4', 'chr4_GL456216_random', 'chr4_GL456350_random', 'chr4_JH584292_random', 'chr4_JH584293_random', 'chr4_JH584294_random', 'chr4_JH584295_random', 'chr5', 'chr5_GL456354_random', 'chr5_JH584296_random', 'chr5_JH584297_random', 'chr5_JH584298_random', 'chr5_JH584299_random', 'chr6', 'chr7', 'chr7_GL456219_random', 'chr8', 'chr9', 'chrM', 'chrUn_GL456239', 'chrUn_GL456359', 'chrUn_GL456360', 'chrUn_GL456366', 'chrUn_GL456367', 'chrUn_GL456368', 'chrUn_GL456370', 'chrUn_GL456372', 'chrUn_GL456378', 'chrUn_GL456379', 'chrUn_GL456381', 'chrUn_GL456382', 'chrUn_GL456383', 'chrUn_GL456385', 'chrUn_GL456387', 'chrUn_GL456389', 'chrUn_GL456390', 'chrUn_GL456392', 'chrUn_GL456393', 'chrUn_GL456394', 'chrUn_GL456396', 'chrUn_JH584304', 'chrX', 'chrX_GL456233_random', 'chrY', 'chrY_JH584300_random', 'chrY_JH584301_random', 'chrY_JH584302_random', 'chrY_JH584303_random']
# Processing chromosome: chr1, length: 195471971
# Shape of all_vals: (10, 195471971)
# Shape of all_vals: (10, 195471971)
# Adding 1681066 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Adding 1681066 intervals for chr1
# Processing chromosome: chr10, length: 130694993
# Shape of all_vals: (10, 130694993)
# Shape of all_vals: (10, 130694993)
# Adding 1115561 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Adding 1115561 intervals for chr10
# Processing chromosome: chr11, length: 122082543
# Shape of all_vals: (10, 122082543)
# Shape of all_vals: (10, 122082543)
# Adding 1059366 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Adding 1059366 intervals for chr11
# Processing chromosome: chr12, length: 120129022
# Shape of all_vals: (10, 120129022)
# Shape of all_vals: (10, 120129022)
# Adding 992936 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Adding 992936 intervals for chr12
# Processing chromosome: chr13, length: 120421639
# Shape of all_vals: (10, 120421639)
# Shape of all_vals: (10, 120421639)
# Adding 1015435 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Adding 1015435 intervals for chr13
# Processing chromosome: chr14, length: 124902244
# Shape of all_vals: (10, 124902244)
# Shape of all_vals: (10, 124902244)
# Adding 1007513 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Adding 1007513 intervals for chr14
# Processing chromosome: chr15, length: 104043685
# Shape of all_vals: (10, 104043685)
# Shape of all_vals: (10, 104043685)
# Adding 887736 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Adding 887736 intervals for chr15
# Processing chromosome: chr16, length: 98207768
# Shape of all_vals: (10, 98207768)
# Shape of all_vals: (10, 98207768)
# Adding 829579 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Adding 829579 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Shape of all_vals: (10, 94987271)
# Shape of all_vals: (10, 94987271)
# Adding 801413 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Adding 801413 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Shape of all_vals: (10, 90702639)
# Shape of all_vals: (10, 90702639)
# Adding 775582 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Adding 775582 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Shape of all_vals: (10, 61431566)
# Shape of all_vals: (10, 61431566)
# Adding 511653 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (10, 169725)
# Adding 806 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (10, 241735)
# Adding 914 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (10, 153618)
# Adding 532 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (10, 39340)
# No non-zero intervals found for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (10, 206961)
# Adding 664 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Adding 511653 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (10, 169725)
# Adding 806 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (10, 241735)
# Adding 914 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (10, 153618)
# Adding 532 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (10, 39340)
# No non-zero intervals found for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (10, 206961)
# Adding 664 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Shape of all_vals: (10, 182113224)
# Shape of all_vals: (10, 182113224)
# Adding 1570244 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Adding 1570244 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Shape of all_vals: (10, 160039680)
# Shape of all_vals: (10, 160039680)
# Adding 1360934 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Adding 1360934 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Shape of all_vals: (10, 156508116)
# Shape of all_vals: (10, 156508116)
# Adding 1313501 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (10, 66673)
# Adding 444 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (10, 227966)
# Adding 4 intervals for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (10, 14945)
# Adding 107 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (10, 207968)
# No non-zero intervals found for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (10, 191905)
# Adding 7 intervals for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (10, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Adding 1313501 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (10, 66673)
# Adding 444 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (10, 227966)
# Adding 4 intervals for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (10, 14945)
# Adding 107 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (10, 207968)
# No non-zero intervals found for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (10, 191905)
# Adding 7 intervals for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (10, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Shape of all_vals: (10, 151834684)
# Shape of all_vals: (10, 151834684)
# Adding 1288128 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (10, 195993)
# Adding 135 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (10, 199368)
# Adding 55 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (10, 205776)
# Adding 65 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (10, 184189)
# Adding 7 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (10, 953012)
# Adding 1039 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Adding 1288128 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (10, 195993)
# Adding 135 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (10, 199368)
# Adding 55 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (10, 205776)
# Adding 65 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (10, 184189)
# Adding 7 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (10, 953012)
# Adding 1039 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Shape of all_vals: (10, 149736546)
# Shape of all_vals: (10, 149736546)
# Adding 1283025 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Adding 1283025 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Shape of all_vals: (10, 145441459)
# Shape of all_vals: (10, 145441459)
# Adding 1189196 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (10, 175968)
# Adding 4 intervals for chr7_GL456219_random
# Processing chromosome: chr8, length: 129401213
# Adding 1189196 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (10, 175968)
# Adding 4 intervals for chr7_GL456219_random
# ...
# Adding 787026 intervals for chr16
# Processing chromosome: chr17, length: 94987271
# Shape of all_vals: (5, 94987271)
# Shape of all_vals: (5, 94987271)
# Adding 755106 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Adding 755106 intervals for chr17
# Processing chromosome: chr18, length: 90702639
# Shape of all_vals: (5, 90702639)
# Shape of all_vals: (5, 90702639)
# Adding 732851 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Adding 732851 intervals for chr18
# Processing chromosome: chr19, length: 61431566
# Shape of all_vals: (5, 61431566)
# Shape of all_vals: (5, 61431566)
# Adding 479113 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (5, 169725)
# Adding 717 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (5, 241735)
# Adding 868 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (5, 153618)
# Adding 510 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (5, 39340)
# Adding 2 intervals for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (5, 206961)
# Adding 622 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Adding 479113 intervals for chr19
# Processing chromosome: chr1_GL456210_random, length: 169725
# Shape of all_vals: (5, 169725)
# Adding 717 intervals for chr1_GL456210_random
# Processing chromosome: chr1_GL456211_random, length: 241735
# Shape of all_vals: (5, 241735)
# Adding 868 intervals for chr1_GL456211_random
# Processing chromosome: chr1_GL456212_random, length: 153618
# Shape of all_vals: (5, 153618)
# Adding 510 intervals for chr1_GL456212_random
# Processing chromosome: chr1_GL456213_random, length: 39340
# Shape of all_vals: (5, 39340)
# Adding 2 intervals for chr1_GL456213_random
# Processing chromosome: chr1_GL456221_random, length: 206961
# Shape of all_vals: (5, 206961)
# Adding 622 intervals for chr1_GL456221_random
# Processing chromosome: chr2, length: 182113224
# Shape of all_vals: (5, 182113224)
# Shape of all_vals: (5, 182113224)
# Adding 1471581 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Adding 1471581 intervals for chr2
# Processing chromosome: chr3, length: 160039680
# Shape of all_vals: (5, 160039680)
# Shape of all_vals: (5, 160039680)
# Adding 1276820 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Adding 1276820 intervals for chr3
# Processing chromosome: chr4, length: 156508116
# Shape of all_vals: (5, 156508116)
# Shape of all_vals: (5, 156508116)
# Adding 1246066 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (5, 66673)
# Adding 400 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (5, 227966)
# Adding 4 intervals for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (5, 14945)
# Adding 85 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (5, 207968)
# Adding 3 intervals for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (5, 191905)
# Adding 7 intervals for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (5, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Adding 1246066 intervals for chr4
# Processing chromosome: chr4_GL456216_random, length: 66673
# Shape of all_vals: (5, 66673)
# Adding 400 intervals for chr4_GL456216_random
# Processing chromosome: chr4_GL456350_random, length: 227966
# Shape of all_vals: (5, 227966)
# Adding 4 intervals for chr4_GL456350_random
# Processing chromosome: chr4_JH584292_random, length: 14945
# Shape of all_vals: (5, 14945)
# Adding 85 intervals for chr4_JH584292_random
# Processing chromosome: chr4_JH584293_random, length: 207968
# Shape of all_vals: (5, 207968)
# Adding 3 intervals for chr4_JH584293_random
# Processing chromosome: chr4_JH584294_random, length: 191905
# Shape of all_vals: (5, 191905)
# Adding 7 intervals for chr4_JH584294_random
# Processing chromosome: chr4_JH584295_random, length: 1976
# Shape of all_vals: (5, 1976)
# Adding 20 intervals for chr4_JH584295_random
# Processing chromosome: chr5, length: 151834684
# Shape of all_vals: (5, 151834684)
# Shape of all_vals: (5, 151834684)
# Adding 1224709 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (5, 195993)
# Adding 103 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (5, 199368)
# Adding 35 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (5, 205776)
# Adding 74 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (5, 184189)
# Adding 8 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (5, 953012)
# Adding 928 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Adding 1224709 intervals for chr5
# Processing chromosome: chr5_GL456354_random, length: 195993
# Shape of all_vals: (5, 195993)
# Adding 103 intervals for chr5_GL456354_random
# Processing chromosome: chr5_JH584296_random, length: 199368
# Shape of all_vals: (5, 199368)
# Adding 35 intervals for chr5_JH584296_random
# Processing chromosome: chr5_JH584297_random, length: 205776
# Shape of all_vals: (5, 205776)
# Adding 74 intervals for chr5_JH584297_random
# Processing chromosome: chr5_JH584298_random, length: 184189
# Shape of all_vals: (5, 184189)
# Adding 8 intervals for chr5_JH584298_random
# Processing chromosome: chr5_JH584299_random, length: 953012
# Shape of all_vals: (5, 953012)
# Adding 928 intervals for chr5_JH584299_random
# Processing chromosome: chr6, length: 149736546
# Shape of all_vals: (5, 149736546)
# Shape of all_vals: (5, 149736546)
# Adding 1212921 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Adding 1212921 intervals for chr6
# Processing chromosome: chr7, length: 145441459
# Shape of all_vals: (5, 145441459)
# Shape of all_vals: (5, 145441459)
# Adding 1123971 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (5, 175968)
# Adding 8 intervals for chr7_GL456219_random
# Processing chromosome: chr8, length: 129401213
# Adding 1123971 intervals for chr7
# Processing chromosome: chr7_GL456219_random, length: 175968
# Shape of all_vals: (5, 175968)
# Adding 8 intervals for chr7_GL456219_random
# Processing chromosome: chr8, length: 129401213
# Shape of all_vals: (5, 129401213)
# Shape of all_vals: (5, 129401213)
# Adding 1049402 intervals for chr8
# Processing chromosome: chr9, length: 124595110
# Adding 1049402 intervals for chr8
# Processing chromosome: chr9, length: 124595110
# Shape of all_vals: (5, 124595110)
# Shape of all_vals: (5, 124595110)
# Adding 1024981 intervals for chr9
# Processing chromosome: chrM, length: 16299
# Shape of all_vals: (5, 16299)
# No non-zero intervals found for chrM
# Processing chromosome: chrUn_GL456239, length: 40056
# Shape of all_vals: (5, 40056)
# Adding 388 intervals for chrUn_GL456239
# Processing chromosome: chrUn_GL456359, length: 22974
# Shape of all_vals: (5, 22974)
# Adding 166 intervals for chrUn_GL456359
# Processing chromosome: chrUn_GL456360, length: 31704
# Shape of all_vals: (5, 31704)
# Adding 220 intervals for chrUn_GL456360
# Processing chromosome: chrUn_GL456366, length: 47073
# Shape of all_vals: (5, 47073)
# Adding 280 intervals for chrUn_GL456366
# Processing chromosome: chrUn_GL456367, length: 42057
# Shape of all_vals: (5, 42057)
# Adding 201 intervals for chrUn_GL456367
# Processing chromosome: chrUn_GL456368, length: 20208
# Shape of all_vals: (5, 20208)
# Adding 106 intervals for chrUn_GL456368
# Processing chromosome: chrUn_GL456370, length: 26764
# Shape of all_vals: (5, 26764)
# Adding 107 intervals for chrUn_GL456370
# Processing chromosome: chrUn_GL456372, length: 28664
# Shape of all_vals: (5, 28664)
# Adding 141 intervals for chrUn_GL456372
# Processing chromosome: chrUn_GL456378, length: 31602
# Shape of all_vals: (5, 31602)
# Adding 216 intervals for chrUn_GL456378
# Processing chromosome: chrUn_GL456379, length: 72385
# Shape of all_vals: (5, 72385)
# Adding 337 intervals for chrUn_GL456379
# Processing chromosome: chrUn_GL456381, length: 25871
# Shape of all_vals: (5, 25871)
# Adding 171 intervals for chrUn_GL456381
# Processing chromosome: chrUn_GL456382, length: 23158
# Shape of all_vals: (5, 23158)
# Adding 94 intervals for chrUn_GL456382
# Processing chromosome: chrUn_GL456383, length: 38659
# Shape of all_vals: (5, 38659)
# Adding 225 intervals for chrUn_GL456383
# Processing chromosome: chrUn_GL456385, length: 35240
# Shape of all_vals: (5, 35240)
# Adding 236 intervals for chrUn_GL456385
# Processing chromosome: chrUn_GL456387, length: 24685
# Shape of all_vals: (5, 24685)
# Adding 174 intervals for chrUn_GL456387
# Processing chromosome: chrUn_GL456389, length: 28772
# Shape of all_vals: (5, 28772)
# Adding 130 intervals for chrUn_GL456389
# Processing chromosome: chrUn_GL456390, length: 24668
# Shape of all_vals: (5, 24668)
# Adding 85 intervals for chrUn_GL456390
# Processing chromosome: chrUn_GL456392, length: 23629
# Shape of all_vals: (5, 23629)
# Adding 176 intervals for chrUn_GL456392
# Processing chromosome: chrUn_GL456393, length: 55711
# Shape of all_vals: (5, 55711)
# Adding 437 intervals for chrUn_GL456393
# Processing chromosome: chrUn_GL456394, length: 24323
# Shape of all_vals: (5, 24323)
# Adding 129 intervals for chrUn_GL456394
# Processing chromosome: chrUn_GL456396, length: 21240
# Shape of all_vals: (5, 21240)
# Adding 111 intervals for chrUn_GL456396
# Processing chromosome: chrUn_JH584304, length: 114452
# Shape of all_vals: (5, 114452)
# Adding 683 intervals for chrUn_JH584304
# Processing chromosome: chrX, length: 171031299
# Adding 1024981 intervals for chr9
# Processing chromosome: chrM, length: 16299
# Shape of all_vals: (5, 16299)
# No non-zero intervals found for chrM
# Processing chromosome: chrUn_GL456239, length: 40056
# Shape of all_vals: (5, 40056)
# Adding 388 intervals for chrUn_GL456239
# Processing chromosome: chrUn_GL456359, length: 22974
# Shape of all_vals: (5, 22974)
# Adding 166 intervals for chrUn_GL456359
# Processing chromosome: chrUn_GL456360, length: 31704
# Shape of all_vals: (5, 31704)
# Adding 220 intervals for chrUn_GL456360
# Processing chromosome: chrUn_GL456366, length: 47073
# Shape of all_vals: (5, 47073)
# Adding 280 intervals for chrUn_GL456366
# Processing chromosome: chrUn_GL456367, length: 42057
# Shape of all_vals: (5, 42057)
# Adding 201 intervals for chrUn_GL456367
# Processing chromosome: chrUn_GL456368, length: 20208
# Shape of all_vals: (5, 20208)
# Adding 106 intervals for chrUn_GL456368
# Processing chromosome: chrUn_GL456370, length: 26764
# Shape of all_vals: (5, 26764)
# Adding 107 intervals for chrUn_GL456370
# Processing chromosome: chrUn_GL456372, length: 28664
# Shape of all_vals: (5, 28664)
# Adding 141 intervals for chrUn_GL456372
# Processing chromosome: chrUn_GL456378, length: 31602
# Shape of all_vals: (5, 31602)
# Adding 216 intervals for chrUn_GL456378
# Processing chromosome: chrUn_GL456379, length: 72385
# Shape of all_vals: (5, 72385)
# Adding 337 intervals for chrUn_GL456379
# Processing chromosome: chrUn_GL456381, length: 25871
# Shape of all_vals: (5, 25871)
# Adding 171 intervals for chrUn_GL456381
# Processing chromosome: chrUn_GL456382, length: 23158
# Shape of all_vals: (5, 23158)
# Adding 94 intervals for chrUn_GL456382
# Processing chromosome: chrUn_GL456383, length: 38659
# Shape of all_vals: (5, 38659)
# Adding 225 intervals for chrUn_GL456383
# Processing chromosome: chrUn_GL456385, length: 35240
# Shape of all_vals: (5, 35240)
# Adding 236 intervals for chrUn_GL456385
# Processing chromosome: chrUn_GL456387, length: 24685
# Shape of all_vals: (5, 24685)
# Adding 174 intervals for chrUn_GL456387
# Processing chromosome: chrUn_GL456389, length: 28772
# Shape of all_vals: (5, 28772)
# Adding 130 intervals for chrUn_GL456389
# Processing chromosome: chrUn_GL456390, length: 24668
# Shape of all_vals: (5, 24668)
# Adding 85 intervals for chrUn_GL456390
# Processing chromosome: chrUn_GL456392, length: 23629
# Shape of all_vals: (5, 23629)
# Adding 176 intervals for chrUn_GL456392
# Processing chromosome: chrUn_GL456393, length: 55711
# Shape of all_vals: (5, 55711)
# Adding 437 intervals for chrUn_GL456393
# Processing chromosome: chrUn_GL456394, length: 24323
# Shape of all_vals: (5, 24323)
# Adding 129 intervals for chrUn_GL456394
# Processing chromosome: chrUn_GL456396, length: 21240
# Shape of all_vals: (5, 21240)
# Adding 111 intervals for chrUn_GL456396
# Processing chromosome: chrUn_JH584304, length: 114452
# Shape of all_vals: (5, 114452)
# Adding 683 intervals for chrUn_JH584304
# Processing chromosome: chrX, length: 171031299
# Shape of all_vals: (5, 171031299)
# Shape of all_vals: (5, 171031299)
# Adding 887244 intervals for chrX
# Processing chromosome: chrX_GL456233_random, length: 336933
# Shape of all_vals: (5, 336933)
# Adding 1811 intervals for chrX_GL456233_random
# Processing chromosome: chrY, length: 91744698
# Adding 887244 intervals for chrX
# Processing chromosome: chrX_GL456233_random, length: 336933
# Shape of all_vals: (5, 336933)
# Adding 1811 intervals for chrX_GL456233_random
# Processing chromosome: chrY, length: 91744698
# Shape of all_vals: (5, 91744698)
# Shape of all_vals: (5, 91744698)
# Adding 47629 intervals for chrY
# Processing chromosome: chrY_JH584300_random, length: 182347
# Shape of all_vals: (5, 182347)
# Adding 1 intervals for chrY_JH584300_random
# Processing chromosome: chrY_JH584301_random, length: 259875
# Shape of all_vals: (5, 259875)
# Adding 1 intervals for chrY_JH584301_random
# Processing chromosome: chrY_JH584302_random, length: 155838
# Shape of all_vals: (5, 155838)
# No non-zero intervals found for chrY_JH584302_random
# Processing chromosome: chrY_JH584303_random, length: 158099
# Shape of all_vals: (5, 158099)
# No non-zero intervals found for chrY_JH584303_random
# Created: /home/sasse/UW/CutandRun/ATACbw/merged_sum_stroma_win100.bw
# Created files: ['/home/sasse/UW/CutandRun/ATACbw/merged_sum_B_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_DC_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_ILC_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_Stem&Prog_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_T.act_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_abT_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_gdT_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_monocyte_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_myeloid_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_stroma_win100.bw']
# Adding 47629 intervals for chrY
# Processing chromosome: chrY_JH584300_random, length: 182347
# Shape of all_vals: (5, 182347)
# Adding 1 intervals for chrY_JH584300_random
# Processing chromosome: chrY_JH584301_random, length: 259875
# Shape of all_vals: (5, 259875)
# Adding 1 intervals for chrY_JH584301_random
# Processing chromosome: chrY_JH584302_random, length: 155838
# Shape of all_vals: (5, 155838)
# No non-zero intervals found for chrY_JH584302_random
# Processing chromosome: chrY_JH584303_random, length: 158099
# Shape of all_vals: (5, 158099)
# No non-zero intervals found for chrY_JH584303_random
# Created: /home/sasse/UW/CutandRun/ATACbw/merged_sum_stroma_win100.bw
# Created files: ['/home/sasse/UW/CutandRun/ATACbw/merged_sum_B_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_DC_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_ILC_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_Stem&Prog_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_T.act_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_abT_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_gdT_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_monocyte_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_myeloid_win100.bw', '/home/sasse/UW/CutandRun/ATACbw/merged_sum_stroma_win100.bw']
